# %% [markdown]
# # StyleGAN2-ADA : Style Conversion - Changing A Dog's Facial Expression

# %% [markdown]
# ### Reference
# - [Paper | Training Generative Adversarial Networks with Limited Data](https://papers.nips.cc/paper/2020/file/8d30aa96e72440759f74bd2306c1fa3d-Paper.pdf)
# - [Official PyTorch implementation | NVlabs | stylegan2-ada-pytorch | github](https://github.com/NVlabs/stylegan2-ada-pytorch)
# - [NVlabs | pre-trained model](https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/)
#
# ![image](https://github.com/NVlabs/stylegan2-ada-pytorch/raw/main/docs/stylegan2-ada-teaser-1024x252.png)

# %% [markdown]
# ---
#
# We will implement the newest and most popular Stylegan2-ada among gans for style conversion, and practice adding expressions to animal photos.
#
# All the codes are based on the [official pytorch implementation](https://github.com/NVlabs/stylegan2-ada-pytorch) and reorganized in the form of a Jupyter notebook for easy reading and practice.
#
# So, let's start step by step by reading the table of contents

# %% [markdown]
# ### index
#
# ```
# Step 1. Initial Setting and load pre-trained model
#      1-a. import libraries
#      1-b. clone the stylegan2-ada's git repository
#      1-c. load pre-trained model that trained on afhqdog dataset
# Step 2. generate sample fake-dog images
#      2-a. a quick look at the model
#      2-b. try submodels : g_mapping, g_synthesis
# Step 3. image morphing
#      3-a. create 2 random vector z and 2 intermediate latent space w
#      3-b. generate 2 target fake-dog images
#      3-c. control `z` and try image interpolation
# Step 4. Project sample image to the latent space of pretrained network
#      4-a. load a target image
#      4-b. transform image file to numpy array
#      4-c. load the pre-trained Generator
#      4-d. Compute w stats
#      4-e. Setup noise inputs
#      4-f. Load VGG16 feature detector
#      4-g. Extract features for target image
#      4-h. Set optimizer and Initiate noise
#      4-i. projection(training)
#      4-j. Compare the target image with the generated image
# Step 5. Style Conversion
#      5-a. Extract information about smiling expressions
#      5-b. Import w to insert facial expressions
# ```

# %% [markdown]
# ### Step 1. Initial Setting and load pre-trained model

# %% [markdown]
# **1-a. Import Libraries**

# %%
import torch
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from PIL import Image

import numpy as np

import copy
import pickle
import os

import matplotlib.pyplot as plt

from tqdm.notebook import tqdm

# %% [markdown]
# **1-b. clone the `stylegan2-ada`'s git repository**

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 1.12 MiB | 1.03 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# %cd stylegan2-ada-pytorch
# Out:
# /kaggle/working/stylegan2-ada-pytorch

# %%
# !ls
# Out:
# Dockerfile	 dataset_tool.py  generate.py	style_mixing.py
# LICENSE.txt	 dnnlib		  legacy.py	torch_utils
# README.md	 docker_run.sh	  metrics	train.py
# calc_metrics.py  docs		  projector.py	training

# %%
# !ls ../../input
# Out:
# afhq-dog-pretrained  animal-faces

# %% [markdown]
# **1-c. load pre-trained model that trained on `afhqdog` dataset**

# %%
with open('../../input/afhq-dog-pretrained/afhqdog.pkl', 'rb') as f:
    G = pickle.load(f)['G_ema'].cuda()

# %% [markdown]
# ### Step 2. generate sample fake-dog images

# %% [markdown]
# **2-a. A quick look at the model**

# %% [markdown]
# The image generator `G` can be used like this :

# %%
z = torch.randn([1, G.z_dim]).cuda()
c = None
img = G(z,c)
# Out:
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.

# %%
img.size()
# Out:
# torch.Size([1, 3, 512, 512])

# %%
torch.min(img)
# Out:
# tensor(-1.3052, device='cuda:0')

# %%
img.squeeze(0).size()
# Out:
# torch.Size([3, 512, 512])

# %%
plt.imshow((img+0.5).cpu().squeeze(0).permute(1,2,0))
plt.axis('off')
plt.show();

# %% [markdown]
# **2-b. Try submodels : g_mapping, g_synthesis**

# %% [markdown]
# It is also possible to divide the G model into submodels.
# - we will use this method in more detail, since we plan to adjust the latent vector later

# %%
g_mapping = G.mapping
g_synthesis = G.synthesis

# %% [markdown]
# Let's take a look at the model structure to see how it is implemented

# %%
g_mapping
# Out:
# MappingNetwork(
#   (fc0): FullyConnectedLayer()
#   (fc1): FullyConnectedLayer()
#   (fc2): FullyConnectedLayer()
#   (fc3): FullyConnectedLayer()
#   (fc4): FullyConnectedLayer()
#   (fc5): FullyConnectedLayer()
#   (fc6): FullyConnectedLayer()
#   (fc7): FullyConnectedLayer()
# )

# %%
g_synthesis
# Out:
# SynthesisNetwork(
#   (b4): SynthesisBlock(
#     (conv1): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (torgb): ToRGBLayer(
#       (affine): FullyConnectedLayer()
#     )
#   )
#   (b8): SynthesisBlock(
#     (conv0): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (conv1): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (torgb): ToRGBLayer(
#       (affine): FullyConnectedLayer()
#     )
#   )
#   (b16): SynthesisBlock(
#     (conv0): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (conv1): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (torgb): ToRGBLayer(
#       (affine): FullyConnectedLayer()
#     )
#   )
#   (b32): SynthesisBlock(
#     (conv0): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (conv1): SynthesisLayer(
#       (affine): FullyConnectedLayer()
#     )
#     (torgb): ToRGBLayer(
#       (affine): FullyConnectedLayer()
#     )
# ...

# %% [markdown]
# make latent vector(space) `z` from random gaussian distribution

# %%
z = torch.randn([1, G.z_dim]).cuda()
z.size()
# Out:
# torch.Size([1, 512])

# %% [markdown]
# transforms `z` into the intermediate latent space `w` (disentangled space)

# %%
w = g_mapping(z, None)
w.size()
# Out:
# torch.Size([1, 16, 512])

# %% [markdown]
# Now pass `w`(transformed `z`) through the synthesis network to create the `fake image`

# %%
img = g_synthesis(w)
img = img.cpu()
img = img.squeeze(0)
img.size()
# Out:
# torch.Size([3, 512, 512])

# %%
plt.imshow((img+0.3).permute(1,2,0))
plt.axis('off')
plt.show();

# %% [markdown]
# ### Step 3. image morphing

# %% [markdown]
# Image Morphing | meaning
# - (computing) The smooth transformation of one image into another

# %% [markdown]
# **3-a. create 2 random vector `z` and 2 intermediate latent space `w`**

# %%
z1 = torch.randn([1, G.z_dim]).cuda()
z2 = torch.randn([1, G.z_dim]).cuda()

w1 = g_mapping(z1, None)
w2 = g_mapping(z2, None)

# %% [markdown]
# **3-b. generate 2 target fake-dog images**

# %%
img1 = g_synthesis(w1)
img2 = g_synthesis(w2)

img1 = img1
img1 = img1.squeeze().permute(1,2,0)

img2 = img2
img2 = img2.squeeze().permute(1,2,0)

# %%
imgs = torch.cat([img1,img2], axis=1).cpu()
imgs.size()
# Out:
# torch.Size([512, 1024, 3])

# %%
plt.imshow(imgs+0.85) # Increase the brightness by adding 0.85 to the pixel values
plt.axis('off')
plt.show()

# %% [markdown]
# **3-c. control `z` and try image interpolation**

# %%
img_group = []
lin = np.linspace(0, 1, 10)
print(*lin) # unpack the list
# Out:
# 0.0 0.1111111111111111 0.2222222222222222 0.3333333333333333 0.4444444444444444 0.5555555555555556 0.6666666666666666 0.7777777777777777 0.8888888888888888 1.0

# %%
with torch.no_grad():
    for i in lin:
        w = ((1-i) * w1) + (i * w2) # style transfrom in for-loop : w1 --> w2
        result = g_synthesis(w)
        result = result.squeeze()
        img_group.append(result)

# %%
img_group = torch.cat(img_group).cpu()
img_group.size()
# Out:
# torch.Size([30, 512, 512])

# %% [markdown]
# This form is not an image. Let's change the shape to `NxCxHxW` and make it an image

# %%
img_group = img_group.view(10,3,512,512)
img_group.size()
# Out:
# torch.Size([10, 3, 512, 512])

# %% [markdown]
# And since we will represent the entire image with one image, let's represent 10(`N`) images as a grid.

# %%
grid_img = torchvision.utils.make_grid(img_group, nrow=5)
grid_img.size()
# Out:
# torch.Size([3, 1030, 2572])

# %%
plt.figure(figsize=(16,6))
plt.imshow(grid_img.permute(1,2,0) +0.85) # The brightness value was also given by 0.85
plt.axis('off')
plt.show()

# %% [markdown]
# ### Step 4. Project sample image to the latent space of pretrained network

# %% [markdown]
# **4-a. load a target image**

# %%
path = '../../input/animal-faces/afhq/train/dog/'

# %%
os.listdir(path)[:10]
# Out:
# ['pixabay_dog_000933.jpg',
#  'pixabay_dog_002339.jpg',
#  'flickr_dog_000998.jpg',
#  'flickr_dog_000236.jpg',
#  'flickr_dog_000136.jpg',
#  'flickr_dog_000614.jpg',
#  'pixabay_dog_003169.jpg',
#  'pixabay_dog_003317.jpg',
#  'flickr_dog_000763.jpg',
#  'pixabay_dog_002424.jpg']

# %%
sample_flickr_dog_path = path+os.listdir(path)[2]
target_img = Image.open(sample_flickr_dog_path)
target_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F19C0053410>

# %% [markdown]
# **4-b. transform image file to numpy array**

# %%
target_img.size
# Out:
# (512, 512)

# %%
target_uint8 = np.array(target_img, dtype=np.uint8)
target_uint8.shape
# Out:
# (512, 512, 3)

# %%
target_uint8[0]
# Out:
# array([[ 7,  9,  6],
#        [ 7,  9,  6],
#        [ 7,  9,  6],
#        ...,
#        [12, 22, 23],
#        [12, 22, 23],
#        [11, 21, 22]], dtype=uint8)

# %% [markdown]
# **4-c. load the pre-trained Generator**

# %%
device = torch.device('cuda')
G_eval = copy.deepcopy(G).eval().requires_grad_(False).to(device) # use g as the evaluation mode (do not track gradients)

# %% [markdown]
# **4-d. Compute `w` stats**

# %%
z_samples = np.random.randn(10000, G_eval.z_dim) # G_eval.z_dim == 512, (10000,512)
w_samples = G_eval.mapping(torch.from_numpy(z_samples).to(device), None)
w_samples.size()
# Out:
# torch.Size([10000, 16, 512])

# %%
w_samples = w_samples[:,:1,:].cpu().numpy().astype(np.float32)
w_samples
# Out:
# array([[[-0.27801913, -0.01979942, -0.17163044, ..., -0.07807784,
#           0.42900476, -0.05428179]],
#
#        [[-0.3051527 , -0.20043162, -0.00686904, ...,  0.30432925,
#           0.7778967 ,  0.20334229]],
#
#        [[-0.09631514, -0.14723678,  0.03708775, ...,  0.59618086,
#           1.2782835 , -0.14736143]],
#
#        ...,
#
#        [[-0.14654855, -0.20909883, -0.13633583, ..., -0.06738123,
#           0.87214196,  1.2596375 ]],
#
#        [[ 0.74779594,  0.50638837, -0.12656619, ...,  0.20644708,
#          -0.07212765,  0.80600756]],
#
#        [[-0.17054725,  0.38892326,  0.01457484, ..., -0.11725987,
#          -0.169078  , -0.06216115]]], dtype=float32)

# %%
w_samples.shape
# Out:
# (10000, 1, 512)

# %%
w_avg = np.mean(w_samples, axis=0, keepdims=True) 
w_avg.shape # mean of w_samples
# Out:
# (1, 1, 512)

# %%
w_std = (np.sum((w_samples - w_avg)**2)/10000)**0.5
w_std
# Out:
# 9.031324307652781

# %% [markdown]
# **4-e. Setup noise inputs**

# %%
noise_bufs = { name: buf for (name, buf) in G.synthesis.named_buffers() if 'noise_const' in name }

# %% [markdown]
# **4-f. Load VGG16 feature detector**

# %%
import dnnlib

# %%
url = 'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metrics/vgg16.pt'
with dnnlib.util.open_url(url) as f:
    vgg16 = torch.jit.load(f).eval().to(device)

# %% [markdown]
# **4-g. Extract features for target image**

# %%
target = torch.tensor(target_uint8.transpose([2,0,1]), device=device)
target.size()
# Out:
# torch.Size([3, 512, 512])

# %%
target = target.unsqueeze(0).to(device).to(torch.float32)
target.size()
# Out:
# torch.Size([1, 3, 512, 512])

# %%
target = F.interpolate(target, size=(256,256), mode='area') # Resize to pass through the vgg16 network.
target.size()
# Out:
# torch.Size([1, 3, 256, 256])

# %%
target_features = vgg16(target, resize_images=False, return_lpips=True)
target_features
# Out:
# tensor([[0.0000e+00, 0.0000e+00, 2.9206e-05,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')

# %%
target_features.size()
# Out:
# torch.Size([1, 7995392])

# %% [markdown]
# **4-h. Set optimizer and Initiate noise**

# %%
# suggested default hyper-parameter (official)
num_steps = 1000
initial_learning_rate = 0.1
# ========================================= #

w_opt = torch.tensor(w_avg, dtype=torch.float32, device=device, requires_grad=True) # pylint: disable=not-callable
w_out = torch.zeros([num_steps] + list(w_opt.shape[1:]), dtype=torch.float32, device=device)
optimizer = torch.optim.Adam([w_opt] + list(noise_bufs.values()), betas=(0.9, 0.999), lr=initial_learning_rate)

# Init noise.
for buf in noise_bufs.values():
    buf[:] = torch.randn_like(buf)
    buf.requires_grad = True

# %% [markdown]
# **4-i. projection(training)**

# %% [markdown]
# - reducing the loss to create an image that mimics the target well.
# - Finding the input vector(w) while generating a well-replicated image.

# %%
num_steps = 1000
# suggested default hyper-parameter (official)
lr_rampdown_length = 0.25
lr_rampup_length = 0.05
initial_noise_factor = 0.05
noise_ramp_length = 0.75
regularize_noise_weight = 1e5
# ========================================= #

for step in tqdm(range(num_steps)):
    # Learning rate schedule.
    t = step / num_steps
    w_noise_scale = w_std * initial_noise_factor * max(0.0, 1.0 - t / noise_ramp_length) ** 2
    lr_ramp = min(1.0, (1.0 - t) / lr_rampdown_length)
    lr_ramp = 0.5 - 0.5 * np.cos(lr_ramp * np.pi)
    lr_ramp = lr_ramp * min(1.0, t / lr_rampup_length)
    lr = initial_learning_rate * lr_ramp
    for param_group in optimizer.param_groups:
            param_group['lr'] = lr
            
    # Synthesize image from opt_w
    w_noise = torch.randn_like(w_opt) * w_noise_scale
    ws = (w_opt + w_noise).repeat([1, G.mapping.num_ws, 1])
    synth_images = G.synthesis(ws, noise_mode='const')
    
    # Downsample image to 256x256 if it's larger than that. VGG was built for 224x224 images.
    synth_images = (synth_images + 1) * (255/2)
    if synth_images.shape[2] > 256:
        synth_images = F.interpolate(synth_images, size=(256, 256), mode='area')
        
    # Features for synth images.
    synth_features = vgg16(synth_images, resize_images=False, return_lpips=True)
    dist = (target_features - synth_features).square().sum() # Calculate the difference between two feature maps (target vs synth) generated through vgg. 
                                                             # This is the point of projection.
    # Noise regularization.
    reg_loss = 0.0
    for v in noise_bufs.values():
        noise = v[None,None,:,:] # must be [1,1,H,W] for F.avg_pool2d()
        while True:
            reg_loss += (noise*torch.roll(noise, shifts=1, dims=3)).mean()**2
            reg_loss += (noise*torch.roll(noise, shifts=1, dims=2)).mean()**2
            if noise.shape[2] <= 8:
                break
            noise = F.avg_pool2d(noise, kernel_size=2)
    loss = dist + reg_loss * regularize_noise_weight
    
    # Step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    print(f'step {step+1:>4d}/{num_steps}: dist {dist:<4.2f} loss {float(loss):<5.2f}')
    
    # Save projected W for each optimization step.
    w_out[step] = w_opt.detach()[0]

    # Normalize noise.
    with torch.no_grad():
        for buf in noise_bufs.values():
            buf -= buf.mean()
            buf *= buf.square().mean().rsqrt()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# step    1/1000: dist 0.40 loss 9.64
# step    2/1000: dist 0.41 loss 9.64
# step    3/1000: dist 0.43 loss 8.09
# step    4/1000: dist 0.44 loss 4.45
# step    5/1000: dist 0.43 loss 1.73
# step    6/1000: dist 0.41 loss 4.62
# step    7/1000: dist 0.44 loss 11.67
# step    8/1000: dist 0.42 loss 12.68
# step    9/1000: dist 0.41 loss 4.80
# step   10/1000: dist 0.43 loss 1.19
# step   11/1000: dist 0.41 loss 8.47
# step   12/1000: dist 0.42 loss 10.19
# step   13/1000: dist 0.39 loss 2.13
# step   14/1000: dist 0.40 loss 3.77
# step   15/1000: dist 0.42 loss 9.47
# step   16/1000: dist 0.40 loss 3.43
# step   17/1000: dist 0.41 loss 3.36
# step   18/1000: dist 0.40 loss 8.06
# step   19/1000: dist 0.42 loss 2.76
# step   20/1000: dist 0.45 loss 4.38
# step   21/1000: dist 0.43 loss 5.95
# step   22/1000: dist 0.40 loss 1.59
# step   23/1000: dist 0.41 loss 5.33
# step   24/1000: dist 0.44 loss 2.31
# step   25/1000: dist 0.43 loss 3.19
# ...

# %%
w_out.size()
# Out:
# torch.Size([1000, 1, 512])

# %%
w_out.repeat([1, G.mapping.num_ws, 1]).size()
# Out:
# torch.Size([1000, 16, 512])

# %%
projected_w_steps = w_out.repeat([1, G.mapping.num_ws, 1])
projected_w = projected_w_steps[-1]
print(projected_w.size())
print(projected_w)
# Out:
# torch.Size([16, 512])
# tensor([[0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897],
#         [0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897],
#         [0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897],
#         ...,
#         [0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897],
#         [0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897],
#         [0.8992, 0.9903, 0.1668,  ..., 3.0016, 0.3878, 1.0897]],
#        device='cuda:0')

# %%
np_w = projected_w.cpu().numpy()
np.save('./projected_w', np_w)

# %% [markdown]
# **4-j. Compare the target image with the generated image**

# %%
synth_image = G.synthesis(projected_w.unsqueeze(0), noise_mode='const')
synth_image = (synth_image + 1) * (255/2)
synth_image = synth_image.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
synth_image.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(np.concatenate((synth_image, target_uint8), axis=1))
plt.axis('off')
plt.title('synth <--  vs  -->  target')
plt.show()

# %% [markdown]
# We will use this method to get the w of the image we want inversely.

# %% [markdown]
# ### Step 5. Style Conversion

# %% [markdown]
# **5-a. Extract information about smiling expressions**

# %% [markdown]
# Load two images of the same breed. One should be expressionless and the other should be an image with a smiling expression.
#
# In fact, for an accurate test (extracting the correct smiling expression), all things other than facial expressions, such as the exact same pose and background, as well as the same breed must be the same. However, in reality, it is difficult to obtain such data, so I will lightly test it with a similar image here.

# %%
target1 = Image.open(path+'flickr_dog_000052.jpg')
target1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F8C29BA6B50>

# %%
target2 = Image.open(path+'flickr_dog_000064.jpg')
target2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F8C29BA77D0>

# %% [markdown]
# I will load `w` obtained by projecting the above image in advance in my personal local environment. You can use the same code learned above. It's exactily same. (but this is too slow in kaggle..)

# %%
projected_w1 = np.load('../../input/afhq-dog-pretrained/projected_w1.npy')
projected_w1 = torch.from_numpy(projected_w1).to(device)
projected_w1.size()
# Out:
# torch.Size([16, 512])

# %%
projected_w2 = np.load('../../input/afhq-dog-pretrained/projected_w2.npy')
projected_w2 = torch.from_numpy(projected_w2).to(device)
projected_w2.size()
# Out:
# torch.Size([16, 512])

# %% [markdown]
# Now that `w` is loaded, let's check whether it is well expressed similarly to the original image.

# %%
synth1 = G.synthesis(projected_w1.unsqueeze(0), noise_mode='const')
synth1 = (synth1 + 1) * (255/2)
synth1 = synth1.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(synth1)
plt.axis('off')
plt.show()

# %%
synth2 = G.synthesis(projected_w2.unsqueeze(0), noise_mode='const')
synth2 = (synth2 + 1) * (255/2)
synth2 = synth2.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(synth2)
plt.axis('off')
plt.show()

# %% [markdown]
# Looks good. Now, let's extract information about the smiling expression. This is really easy. just subtract

# %%
to_smile_w = projected_w1 - projected_w2

# %% [markdown]
# Let's just have fun with what the smiley expression space looks like

# %%
smile = G.synthesis(to_smile_w.unsqueeze(0), noise_mode='const')
smile = (smile + 1) * (255/2)
smile = smile.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(smile)

# %% [markdown]
# **5-b. Import w to insert facial expressions**

# %% [markdown]
# - load first image

# %%
projected_test_w = np.load('../../input/afhq-dog-pretrained/projected_test_w.npy')
projected_test_w = torch.from_numpy(projected_test_w).to(device)
projected_test_w.size()
# Out:
# torch.Size([16, 512])

# %%
synth_test = G.synthesis(projected_test_w.unsqueeze(0), noise_mode='const')
synth_test = (synth_test + 1) * (255/2)
synth_test = synth_test.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(synth_test)
plt.axis('off')
plt.show()

# %% [markdown]
# - insert `smile` into first image

# %%
synth_test_smile = G.synthesis((projected_test_w+to_smile_w*0.38).unsqueeze(0), noise_mode='const')
synth_test_smile = (synth_test_smile + 1) * (255/2)
synth_test_smile = synth_test_smile.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

plt.imshow(synth_test_smile)
plt.axis('off')
plt.show()

# %% [markdown]
# ---
# - load second image

# %%
projected_test_w2 = np.load('../../input/afhq-dog-pretrained/projected_test_w-2.npy')
projected_test_w2 = torch.from_numpy(projected_test_w2).to(device)
projected_test_w2.size()
# Out:
# torch.Size([16, 512])

# %%
synth_test2 = G.synthesis(projected_test_w2.unsqueeze(0), noise_mode='const')
synth_test2 = (synth_test2 + 1) * (255/2)
synth_test2 = synth_test2.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(synth_test2)
plt.axis('off')
plt.show()

# %% [markdown]
# - insert `smile` into second image

# %%
synth_test_smile2 = G.synthesis((projected_test_w2+to_smile_w*0.38).unsqueeze(0), noise_mode='const')
synth_test_smile2 = (synth_test_smile2 + 1) * (255/2)
synth_test_smile2 = synth_test_smile2.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

plt.imshow(synth_test_smile2)
plt.axis('off')
plt.show()

# %% [markdown]
# ---
# - and third image

# %%
projected_test_w3 = np.load('../../input/afhq-dog-pretrained/projected_test_w-3.npy')
projected_test_w3 = torch.from_numpy(projected_test_w3).to(device)
projected_test_w3.size()
# Out:
# torch.Size([16, 512])

# %%
synth_test3 = G.synthesis(projected_test_w3.unsqueeze(0), noise_mode='const')
synth_test3 = (synth_test3 + 1) * (255/2)
synth_test3 = synth_test3.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

# %%
plt.imshow(synth_test3)
plt.axis('off')
plt.show()

# %% [markdown]
# - insert `smile` into third image

# %%
synth_test_smile3 = G.synthesis((projected_test_w3+to_smile_w*0.38).unsqueeze(0), noise_mode='const')
synth_test_smile3 = (synth_test_smile3 + 1) * (255/2)
synth_test_smile3 = synth_test_smile3.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

plt.imshow(synth_test_smile3)
plt.axis('off')
plt.show()

# %% [markdown]
# - Put them all together and compare:

# %%
group0 = np.concatenate((synth2, synth1))
group1 = np.concatenate((synth_test, synth_test_smile))
group2 = np.concatenate((synth_test2, synth_test_smile2))
group3 = np.concatenate((synth_test3, synth_test_smile3))

plt.figure(figsize=(16,6))
plt.imshow(np.concatenate((group0,group1,group2,group3),axis=1))
plt.axis('off')
plt.show()

# %% [markdown]
# we extracted the vector for the smiling expression from the first column and applied it to the images of dogs of different breeds in the second, third, and fourth columns.
#
# As a result of the test, it was applied with a very accurate point to an image with a similar shape, and it can be expected that it will create a fairly accurate style change for the same breed.

# %% [markdown]
# ✋Thank you so much for reading the really long code up to here.
#
# If it was helpful, please upvote it so more people can see it, and leave a comment if you have any questions.
#
#
# See you again in another kernel!
