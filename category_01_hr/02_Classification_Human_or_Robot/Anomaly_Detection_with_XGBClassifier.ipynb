# %% [markdown]
# ## Anomaly Detection with XGB Classifier(base model Accuracy 79%) - Facebook Recruiting IV: Human or Robot?

# %% [markdown]
# 이 대회에는 두 개의 데이터 세트가 있습니다. 하나는 ID, 지불 계정 및 주소를 포함한 입찰자 정보 목록을 포함하는 입찰자 데이터 세트입니다. 다른 하나는 서로 다른 경매에 대한 760 만 개의 입찰을 포함하는 입찰 데이터 세트입니다. 이 데이터 세트의 입찰은 모두 휴대 기기에서 이루어집니다.
#
# 온라인 경매 플랫폼은 각 입찰에 대해 고정 된 금액 증가분을 가지므로 각 입찰에 대한 금액을 포함하지 않습니다. 입찰, 경매 또는 장치에서 입찰 행동을 배우는 것을 환영합니다.
#
# There are two datasets in this competition. One is a bidder dataset that includes a list of bidder information, including their id, payment account, and address. The other is a bid dataset that includes 7.6 million bids on different auctions. The bids in this dataset are all made by mobile devices.
#
# The online auction platform has a fixed increment of dollar amount for each bid, so it doesn't include an amount for each bid. You are welcome to learn the bidding behavior from the time of the bids, the auction, or the device.
#
#
# [데이터셋 다운로드 링크](https://bit.ly/3uIL3Fl)
#
# ### File descriptions
#
# - train.csv - the training set from the bidder dataset
# - test.csv - the test set from the bidder dataset
# - sampleSubmission.csv - a sample submission file in the correct format
# - bids.csv - the bid dataset
#
# ### Data fields
# **bidder dataset**
#
# - bidder_id – Unique identifier of a bidder.
# - payment_account – Payment account associated with a bidder. These are obfuscated to protect privacy.
# - address – Mailing address of a bidder. These are obfuscated to protect privacy.
# - (target 데이터) **outcome** – Label of a bidder indicating whether or not it is a robot. Value 1.0 indicates a robot, where value 0.0 indicates human.
# The outcome was half hand labeled, half stats-based. There are two types of "bots" with different levels of proof:
#
# 1. Bidders who are identified as bots/fraudulent with clear proof. Their accounts were banned by the auction site.
#
# 2. Bidder who may have just started their business/clicks or their stats exceed from system wide average. There are no clear proof that they are bots.
#
#
# **bid dataset**
#
# - bid_id - unique id for this bid
# - bidder_id – Unique identifier of a bidder (same as the bidder_id used in train.csv and test.csv)
# - auction – Unique identifier of an auction
# - merchandise –  The category of the auction site campaign, which means the bidder might come to this site by way of searching for "home goods" but ended up bidding for "sporting goods" - and that leads to this field being "home goods". This categorical field could be a search term, or online advertisement.
# - device – Phone model of a visitor
# - time - Time that the bid is made (transformed to protect privacy).
# - country - The country that the IP belongs to
# - ip – IP address of a bidder (obfuscated to protect privacy).
# - url - url where the bidder was referred from (obfuscated to protect privacy).
#
# 참고링크: https://www.kaggle.com/c/facebook-recruiting-iv-human-or-bot/data

# %% [markdown]
# ---
# - Step 1. Data load & EDA
# - Step 2. Preprocessing - replace all values with count number
# - Step 3. Preprocessing - Upsampling
# - Step 4. Train / Valid Set Split
# - Step 5. Modeling
# - Step 6. Prediction

# %% [markdown]
# ### Step 1. Data load & EDA

# %%
import pandas as pd

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
train_df.head()
# Out:
#                                bidder_id  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1  624f258b49e77713fc34034560f93fb3hu3jo
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj
# 3  4bee9aba2abda51bf43d639013d6efe12iycd
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228754av
# 1  a3d2de7675556553a5f08e4c88d2c228v1sga
# 2  a3d2de7675556553a5f08e4c88d2c2280cybl
# 3  51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4  a3d2de7675556553a5f08e4c88d2c22857ddh
#
#                                  address  outcome
# 0  a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0
# 1  ae87054e5a97a8f840a3991d12611fdcrfbq3      0.0
# 2  92520288b50f03907041887884ba49c0cl0pd      0.0
# 3  4cb9717c8ad7e88a9a284989dd79b98dbevyi      0.0
# 4  2a96c3ce94b3be921e0296097b88b56a7x1ji      0.0

# %%
test_df.head()
# Out:
#                                bidder_id  \
# 0  49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1  a921612b85a1494456e74c09393ccb65ylp4y
# 2  6b601e72a4d264dab9ace9d7b229b47479v6i
# 3  eaf0ed0afc9689779417274b4791726cn5udi
# 4  cdecd8d02ed8c6037e38042c7745f688mx5sf
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228htx90
# 1  a3d2de7675556553a5f08e4c88d2c228rs17i
# 2  925381cce086b8cc9594eee1c77edf665zjpl
# 3  a3d2de7675556553a5f08e4c88d2c228nclv5
# 4  a3d2de7675556553a5f08e4c88d2c228dtdkd
#
#                                  address
# 0  5d9fa1b71f992e7c7a106ce4b07a0a754le7c
# 1  a3d2de7675556553a5f08e4c88d2c228klidn
# 2  a3d2de7675556553a5f08e4c88d2c228aght0
# 3  b5714de1fd69d4a0d2e39d59e53fe9e15vwat
# 4  c3b363a3c3b838d58c85acf0fc9964cb4pnfa

# %%
bids = pd.read_csv('./data/bids.csv')

# %%
bids.head()
# Out:
#    bid_id                              bidder_id auction merchandise  device  \
# 0       0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr     jewelry  phone0
# 1       1  668d393e858e8126275433046bbd35c6tywop   aeqok   furniture  phone1
# 2       2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e  home goods  phone2
# 3       3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix     jewelry  phone4
# 4       4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix     jewelry  phone5
#
#                time country              ip              url
# 0  9759243157894736      us   69.166.231.58  vasstdc27m7nks3
# 1  9759243157894736      in   50.201.125.84  jmqlhflrzwuay9c
# 2  9759243157894736      py  112.54.208.157  vasstdc27m7nks3
# 3  9759243157894736      in   18.99.175.133  vasstdc27m7nks3
# 4  9759243157894736      in    145.138.5.37  vasstdc27m7nks3

# %%
train_df['bidder_id'].nunique()
# Out:
# 2013

# %%
bids['bidder_id'].nunique()
# Out:
# 6614

# %% [markdown]
# Check - train set

# %%
train_df.nunique()
# Out:
# bidder_id          2013
# payment_account    2013
# address            2013
# outcome               2
# dtype: int64

# %%
train_df.isnull().sum()
# Out:
# bidder_id          0
# payment_account    0
# address            0
# outcome            0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bidder_id        2013 non-null   object
#  1   payment_account  2013 non-null   object
#  2   address          2013 non-null   object
#  3   outcome          2013 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 63.0+ KB

# %% [markdown]
# ---
# **All bidder_id are unique. - 2013**

# %% [markdown]
# Check - bids

# %%
bids.isnull().sum()
# Out:
# bid_id            0
# bidder_id         0
# auction           0
# merchandise       0
# device            0
# time              0
# country        8859
# ip                0
# url               0
# dtype: int64

# %%
bids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7656334 entries, 0 to 7656333
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   bid_id       int64
#  1   bidder_id    object
#  2   auction      object
#  3   merchandise  object
#  4   device       object
#  5   time         int64
#  6   country      object
#  7   ip           object
#  8   url          object
# dtypes: int64(2), object(7)
# memory usage: 525.7+ MB

# %%
bids.nunique()
# Out:
# bid_id         7656334
# bidder_id         6614
# auction          15051
# merchandise         10
# device            7351
# time            776529
# country            199
# ip             2303991
# url            1786351
# dtype: int64

# %% [markdown]
# Check - test set

# %%
test_df.isnull().sum()
# Out:
# bidder_id          0
# payment_account    0
# address            0
# dtype: int64

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bidder_id        4700 non-null   object
#  1   payment_account  4700 non-null   object
#  2   address          4700 non-null   object
# dtypes: object(3)
# memory usage: 110.3+ KB

# %%
test_df.nunique()
# Out:
# bidder_id          4700
# payment_account    4700
# address            4700
# dtype: int64

# %%
bids.country.isnull().sum() / len(bids.country)
# Out:
# 0.0011570811827174728

# %%
sample = pd.read_csv('./data/sampleSubmission.csv')

# %%
sample
# Out:
#                                   bidder_id  prediction
# 0     49bb5a3c944b8fc337981cc7a9ccae41u31d7         0.0
# 1     a921612b85a1494456e74c09393ccb65ylp4y         0.0
# 2     6b601e72a4d264dab9ace9d7b229b47479v6i         0.0
# 3     eaf0ed0afc9689779417274b4791726cn5udi         0.0
# 4     cdecd8d02ed8c6037e38042c7745f688mx5sf         0.0
# ...                                     ...         ...
# 4695  bef56983ba78b2ee064443ae95972877jfkyd         0.0
# 4696  4da45cc915c32d4368ac7e773d92d4affwqrr         0.0
# 4697  0d0e6220bf59ab9a0c5b5987fb2c34a9p33f9         0.0
# 4698  4981c32c54dde65b79dbc48fd9ab6457caqze         0.0
# 4699  7ade70030d559a6c255be2f6feca17acnrqs0         0.0
#
# [4700 rows x 2 columns]

# %%
bids
# Out:
#           bid_id                              bidder_id auction  \
# 0              0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr
# 1              1  668d393e858e8126275433046bbd35c6tywop   aeqok
# 2              2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e
# 3              3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix
# 4              4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix
# ...          ...                                    ...     ...
# 7656329  7656329  626159dd6f2228ede002d9f9340f75b7puk8d   3e64w
# 7656330  7656330  a318ea333ceee1ba39a494476386136a826dv   xn0y0
# 7656331  7656331  f5b2bbad20d1d7ded3ed960393bec0f40u6hn   gja6c
# 7656332  7656332  d4bd412590f5106b9d887a43c51b254eldo4f   hmwk8
# 7656333  7656333  0ea62aaa9c3ffcc6db584cb69c1f6c4bcripp   c9ox9
#
#             merchandise    device              time country              ip  \
# 0               jewelry    phone0  9759243157894736      us   69.166.231.58
# 1             furniture    phone1  9759243157894736      in   50.201.125.84
# 2            home goods    phone2  9759243157894736      py  112.54.208.157
# 3               jewelry    phone4  9759243157894736      in   18.99.175.133
# 4               jewelry    phone5  9759243157894736      in    145.138.5.37
# ...                 ...       ...               ...     ...             ...
# 7656329         jewelry   phone91  9709222052631578      ru  140.204.227.63
# 7656330          mobile  phone236  9709222052631578      pl  24.232.159.118
# 7656331  sporting goods   phone80  9709222052631578      za   80.237.28.246
# 7656332         jewelry  phone349  9709222052631578      my   91.162.27.152
# 7656333          mobile   phone82  9709222052631578      jo  160.243.101.60
#
#                      url
# 0        vasstdc27m7nks3
# 1        jmqlhflrzwuay9c
# 2        vasstdc27m7nks3
# 3        vasstdc27m7nks3
# 4        vasstdc27m7nks3
# ...                  ...
# 7656329  cghhmomsaxi6pug
# 7656330  wgggpdg2gx5pesn
# 7656331  5xgysg14grlersa
# 7656332  bhtrek44bzi2wfl
# 7656333  vasstdc27m7nks3
#
# [7656334 rows x 9 columns]

# %% [markdown]
# ### Step 2. Preprocessing - replace all values with count number
# 특정 bidder_id가 특정 auction / merchandise / device / time / country / ip / url 에서 중복으로 나타나는 빈도로 값을 치환한다.

# %%
bids.groupby(['bidder_id','auction']).size()
# Out:
# bidder_id                              auction
# 001068c415025a009fee375a12cff4fcnht8y  4ifac      1
# 002d229ffb247009810828f648afc2ef593rb  2tdw2      2
# 0030a2dd87ad2733e0873062e4f83954mkj86  obbny      1
# 003180b29c6a5f8f1d84a6b7b6f7be57tjj1o  cqsh6      1
#                                        efh5o      1
#                                                  ..
# ffd62646d600b759a985d45918bd6f0431vmz  wthc6      1
#                                        yfjur      7
#                                        yv5hw      5
#                                        zz4dz      5
# fff2c070d8200e0a09150bd81452ce29ngcnv  2zggz      1
# Length: 382341, dtype: int64

# %%
auction = pd.DataFrame({'count' : bids.groupby(['bidder_id','auction']).size()}).reset_index()

# %%
auction
# Out:
#                                     bidder_id auction  count
# 0       001068c415025a009fee375a12cff4fcnht8y   4ifac      1
# 1       002d229ffb247009810828f648afc2ef593rb   2tdw2      2
# 2       0030a2dd87ad2733e0873062e4f83954mkj86   obbny      1
# 3       003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   cqsh6      1
# 4       003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   efh5o      1
# ...                                       ...     ...    ...
# 382336  ffd62646d600b759a985d45918bd6f0431vmz   wthc6      1
# 382337  ffd62646d600b759a985d45918bd6f0431vmz   yfjur      7
# 382338  ffd62646d600b759a985d45918bd6f0431vmz   yv5hw      5
# 382339  ffd62646d600b759a985d45918bd6f0431vmz   zz4dz      5
# 382340  fff2c070d8200e0a09150bd81452ce29ngcnv   2zggz      1
#
# [382341 rows x 3 columns]

# %%
auction.set_index('auction')['count']
# Out:
# auction
# 4ifac    1
# 2tdw2    2
# obbny    1
# cqsh6    1
# efh5o    1
#         ..
# wthc6    1
# yfjur    7
# yv5hw    5
# zz4dz    5
# 2zggz    1
# Name: count, Length: 382341, dtype: int64

# %%
# 메모리 과부하. killed
bids.replace(auction.set_index('auction')['count'].to_dict())

# %%
cols = ['auction', 'merchandise','device','time','ip','url']

# %% [markdown]
# > 과부하로 코드 변경하였음. 아래 replace 구문 사용하지 않음.

# %%
count = 0
for col in cols:
    count += 1
    print('진행 중 - {}/7'.format(count))
    col_df = pd.DataFrame({'count' : bids.groupby(['bidder_id',col]).size()}).reset_index()
    bids.replace(col_df.set_index(col)['count'].to_dict())
# Out:
# 진행 중 - 1/7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-d16a2192579e> in <module>
#       4     print('진행 중 - {}/7'.format(count))
#       5     col_df = pd.DataFrame({'count' : bids.groupby(['bidder_id',col]).size()}).reset_index()
# ----> 6     bids.replace(col_df.set_index(col)['count'].to_dict())
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6644
#    6645             return self.replace(
# -> 6646                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6647             )
#    6648         else:
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6697                         dest_list=value,
#    6698                         inplace=inplace,
# -> 6699                         regex=regex,
#    6700                     )
#    6701
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/internals/managers.py in comp(s, regex)
#     609                     maybe_convert_objects(values), s.asm8, regex
#     610                 )
# --> 611             return _compare_or_regex_search(values, s, regex)
#     612
#     613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex)
#    1922         result = False
#    1923     else:
# -> 1924         result = op(a)
#    1925
#    1926     if is_scalar(result) and (is_a_array or is_b_array):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/pandas/core/internals/managers.py in <lambda>(x)
#    1909     """
#    1910     if not regex:
# -> 1911         op = lambda x: operator.eq(x, b)
#    1912     else:
#    1913         op = np.vectorize(
#
# KeyboardInterrupt:

# %%
bids.drop('country',axis=1, inplace=True)

# %% [markdown]
# > apply + lambda 조합으로 대체

# %%
count = 0
for col in cols:
    count += 1
    print('진행 중 - {}/6'.format(count))
    col_df = pd.DataFrame({'count' : bids.groupby(['bidder_id',col]).size()}).reset_index()
    col_df = col_df.set_index(col)['count'].to_dict()
    bids[col] = bids[col].apply(lambda x : col_df[x])
# Out:
# 진행 중 - 1/6
# 진행 중 - 2/6
# 진행 중 - 3/6
# 진행 중 - 4/6
# 진행 중 - 5/6
# 진행 중 - 6/6

# %%
bids
# Out:
#           bid_id                              bidder_id  auction  merchandise  \
# 0              0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8       35            3
# 1              1  668d393e858e8126275433046bbd35c6tywop       16         2917
# 2              2  aa5f360084278b35d746fa6af3a7a1a5ra3xe       16            1
# 3              3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi        1            3
# 4              4  8393c48eaf4b8fa96886edc7cf27b372dsibi        1            3
# ...          ...                                    ...      ...          ...
# 7656329  7656329  626159dd6f2228ede002d9f9340f75b7puk8d        1            3
# 7656330  7656330  a318ea333ceee1ba39a494476386136a826dv        1          664
# 7656331  7656331  f5b2bbad20d1d7ded3ed960393bec0f40u6hn       47            1
# 7656332  7656332  d4bd412590f5106b9d887a43c51b254eldo4f       42            3
# 7656333  7656333  0ea62aaa9c3ffcc6db584cb69c1f6c4bcripp       12          664
#
#          device  time    ip   url
# 0            72     1     1     1
# 1           161     1   108     7
# 2            21     1     4     1
# 3           200     1     1     1
# 4            25     1     1     1
# ...         ...   ...   ...   ...
# 7656329       1     1     4     1
# 7656330     123     1     4     1
# 7656331      21     1     1     3
# 7656332     160     1  1209  1445
# 7656333     164     1     1     1
#
# [7656334 rows x 8 columns]

# %%
bids.drop('bid_id',axis=1,inplace=True)

# %%
pd.merge(train_df,bids, on='bidder_id')
# Out:
#                                      bidder_id  \
# 0        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 2        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 3        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 4        91a3c57b13234af24875c56fb7e2b2f4rb56a
# ...                                        ...
# 3071219  c806dbb2decba0ed3c4ff5e2e60a74c2wjvbl
# 3071220  c806dbb2decba0ed3c4ff5e2e60a74c2wjvbl
# 3071221  0381a69b7a061e9ace2798fd48f1f537mgq57
# 3071222  84a769adc98498f52debfe57b93a0789556f4
# 3071223  84a769adc98498f52debfe57b93a0789556f4
#
#                                payment_account  \
# 0        a3d2de7675556553a5f08e4c88d2c228754av
# 1        a3d2de7675556553a5f08e4c88d2c228754av
# 2        a3d2de7675556553a5f08e4c88d2c228754av
# 3        a3d2de7675556553a5f08e4c88d2c228754av
# 4        a3d2de7675556553a5f08e4c88d2c228754av
# ...                                        ...
# 3071219  a3d2de7675556553a5f08e4c88d2c22856leq
# 3071220  a3d2de7675556553a5f08e4c88d2c22856leq
# 3071221  fd87037ce0304077079c749f420f0b4c54uo0
# 3071222  fbe0ce34d6546ebd9e4c63afc68b085byd2tf
# 3071223  fbe0ce34d6546ebd9e4c63afc68b085byd2tf
#
#                                        address  outcome  auction  merchandise  \
# 0        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       16            1
# 1        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       24            1
# 2        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       16            1
# 3        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       12            1
# 4        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       24            1
# ...                                        ...      ...      ...          ...
# 3071219  d02c2b288b8aabd79ff47118aff41a2dqwzwc      0.0        1          664
# 3071220  d02c2b288b8aabd79ff47118aff41a2dqwzwc      0.0        1          664
# 3071221  f030a221726fbcdfc4dc7dfd1b381a112hieq      0.0       42          553
# 3071222  a3d2de7675556553a5f08e4c88d2c228fib6p      0.0        1            3
# 3071223  a3d2de7675556553a5f08e4c88d2c228fib6p      0.0        1            3
#
#          device  time    ip  url
# 0            72     1     1    1
# 1            27     1   216    1
# 2           200     1     1    1
# 3           200     1     1    1
# 4           200     1     1    1
# ...         ...   ...   ...  ...
# 3071219      36     1     1    2
# 3071220      17     1   696    2
# 3071221      72     1  1209    1
# 3071222     306     1     4    2
# 3071223     306     1     4    2
#
# [3071224 rows x 10 columns]

# %% [markdown]
# ### Step 3. Preprocessing - Upsampling

# %%
train_df = pd.merge(train_df,bids, on='bidder_id')

# %%
train_df['outcome'].value_counts()
# Out:
# 0.0    2658808
# 1.0     412416
# Name: outcome, dtype: int64

# %%
from sklearn.utils import resample

# %%
df_0 = train_df[train_df['outcome']==0]
df_1 = train_df[train_df['outcome']==1]

# Upsample minority class
df_upsample_1 = resample(df_1,
                         replace=True, 
                         n_samples=2658808,
                         random_state=111, 
                        )

df_upsampled = pd.concat([df_0, df_upsample_1])

df_upsampled['outcome'].value_counts()
# Out:
# 1.0    2658808
# 0.0    2658808
# Name: outcome, dtype: int64

# %%
train_df = df_upsampled

# %%
train_df
# Out:
#                                      bidder_id  \
# 0        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 2        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 3        91a3c57b13234af24875c56fb7e2b2f4rb56a
# 4        91a3c57b13234af24875c56fb7e2b2f4rb56a
# ...                                        ...
# 781977   d2704c8bb6ebbf13e08f37131382b126wy4yc
# 1064484  1aa485901ede7baf78ea116e297e9d7f9en6i
# 1493713  9655ccc7c0c193f1549475f02c54dce45kjw7
# 2144450  44bfa21b7d497f097a594c8861d4f8d4w5e97
# 1614860  9655ccc7c0c193f1549475f02c54dce45kjw7
#
#                                payment_account  \
# 0        a3d2de7675556553a5f08e4c88d2c228754av
# 1        a3d2de7675556553a5f08e4c88d2c228754av
# 2        a3d2de7675556553a5f08e4c88d2c228754av
# 3        a3d2de7675556553a5f08e4c88d2c228754av
# 4        a3d2de7675556553a5f08e4c88d2c228754av
# ...                                        ...
# 781977   308f53abff7d25a618069ec8b74feecexmpf3
# 1064484  a3d2de7675556553a5f08e4c88d2c228n1tgz
# 1493713  a04bad750c3144125fb80a399273bfa1wi6hx
# 2144450  5c0fc5af3b1ae4a5acd28349a71134a13x7o5
# 1614860  a04bad750c3144125fb80a399273bfa1wi6hx
#
#                                        address  outcome  auction  merchandise  \
# 0        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       16            1
# 1        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       24            1
# 2        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       16            1
# 3        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       12            1
# 4        a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0       24            1
# ...                                        ...      ...      ...          ...
# 781977   a3d2de7675556553a5f08e4c88d2c228djz03      1.0      370          664
# 1064484  ca8d4b018cb62966eebb2974f5a83b4fo1zpr      1.0        1            1
# 1493713  fcec7ba7b352f0a5e62ca742391e8ab3yylj7      1.0       42            1
# 2144450  a3d2de7675556553a5f08e4c88d2c228irh1c      1.0        1          664
# 1614860  fcec7ba7b352f0a5e62ca742391e8ab3yylj7      1.0      144            1
#
#          device  time   ip  url
# 0            72     1    1    1
# 1            27     1  216    1
# 2           200     1    1    1
# 3           200     1    1    1
# 4           200     1    1    1
# ...         ...   ...  ...  ...
# 781977       17     1    1    2
# 1064484     166     1  395    8
# 1493713      27     1    4    1
# 2144450     216  2768    4    1
# 1614860      72  2768    1    1
#
# [5317616 rows x 10 columns]

# %%
X = train_df.drop(['bidder_id','payment_account','address','outcome'], axis=1)
y = train_df['outcome']

# %% [markdown]
# ### Step 4. Train / Valid Set Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=111)

# %%
print(X_train.shape, y_train.shape, X_valid.shape, y_valid.shape)
# Out:
# (3988212, 6) (3988212,) (1329404, 6) (1329404,)

# %%
X_train
# Out:
#          auction  merchandise  device  time    ip  url
# 2586287       36            1       1  2768    29   33
# 2150317       42            1     175     1     1    1
# 2015289        1            1       1   246     1    1
# 1092321        1            1      58     1   696    1
# 1561172       16            1      36     1     1    1
# ...          ...          ...     ...   ...   ...  ...
# 2004758      210          664     274     1  1209    1
# 2579389       16            1      36  2768    11    1
# 776796         1            1       1  2768   342    1
# 2161363      135            3      72     1    42    1
# 1562102       42            1      72     1     4    1
#
# [3988212 rows x 6 columns]

# %% [markdown]
# ### Step 5. Modeling

# %% [markdown]
# > 메모리 누수(?)로 grid_cv 사용하지 않음. xgboost(default parameters)로 대체

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

params = {'n_estimators' : [10, 20, 30, 40, 50],
          'max_depth' : [6, 8, 10]
         }

model = RandomForestClassifier(random_state=111)
grid_cv = GridSearchCV(model, param_grid=params, cv=3) 

grid_cv.fit(X_train, y_train)
print('Best Hyper-Parameter : {}'.format(grid_cv.best_params_))
print('Best Accuracy : {:.4f}'.format(grid_cv.best_score_))

best_params = grid_cv.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-6b469a25386a> in <module>
#       9 grid_cv = GridSearchCV(model, param_grid=params, cv=3)
#      10
# ---> 11 grid_cv.fit(X_train, y_train)
#      12 print('Best Hyper-Parameter : {}'.format(grid_cv.best_params_))
#      13 print('Best Accuracy : {:.4f}'.format(grid_cv.best_score_))
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     390                     verbose=self.verbose, class_weight=self.class_weight,
#     391                     n_samples_bootstrap=n_samples_bootstrap)
# --> 392                 for i, t in enumerate(trees))
#     393
#     394             # Collect newly grown trees
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     892             sample_weight=sample_weight,
#     893             check_input=check_input,
# --> 894             X_idx_sorted=X_idx_sorted)
#     895         return self
#     896
#
# ~/opt/anaconda3/envs/dataScience/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
import xgboost as xgb

model = xgb.XGBClassifier(n_estimators=100)

# %%
# model = RandomForestClassifier(best_params) 메모리 누수로 사용x

model.fit(X_train, y_train)

print('Train Accuracy : {:.2f}'.format(model.score(X_train, y_train)))
print('Test Accuracy : {:.2f}'.format(model.score(X_valid, y_valid)))
# Out:
# Train Accuracy : 0.79
# Test Accuracy : 0.79

# %%
test_df = pd.merge(test_df,bids, on='bidder_id')

# %% [markdown]
# ### Step 6. Prediction

# %%
for_test = test_df.drop(['bidder_id','payment_account','address'], axis=1)

# %%
pred = model.predict(for_test)

# %%
pred
# Out:
# array([0., 1., 1., ..., 1., 1., 0.])

# %%
test_df['bidder_id']
# Out:
# 0          49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1          49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 2          49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 3          49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 4          a921612b85a1494456e74c09393ccb65ylp4y
#                            ...
# 4585105    7ade70030d559a6c255be2f6feca17acnrqs0
# 4585106    7ade70030d559a6c255be2f6feca17acnrqs0
# 4585107    7ade70030d559a6c255be2f6feca17acnrqs0
# 4585108    7ade70030d559a6c255be2f6feca17acnrqs0
# 4585109    7ade70030d559a6c255be2f6feca17acnrqs0
# Name: bidder_id, Length: 4585110, dtype: object

# %%
pred_df = pd.DataFrame(pred, columns=['prediction'])

# %%
id_df = pd.DataFrame(test_df['bidder_id'])

# %%
submission = pd.concat([id_df, pred_df], axis=1)

# %%
submission
# Out:
#                                      bidder_id  prediction
# 0        49bb5a3c944b8fc337981cc7a9ccae41u31d7         0.0
# 1        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 2        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 3        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 4        a921612b85a1494456e74c09393ccb65ylp4y         0.0
# ...                                        ...         ...
# 4585105  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585106  7ade70030d559a6c255be2f6feca17acnrqs0         0.0
# 4585107  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585108  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585109  7ade70030d559a6c255be2f6feca17acnrqs0         0.0
#
# [4585110 rows x 2 columns]

# %%
submission.to_csv('./data/sampleSubmission.csv', index=False)

# %%
pd.read_csv('./data/sampleSubmission.csv')
# Out:
#                                      bidder_id  prediction
# 0        49bb5a3c944b8fc337981cc7a9ccae41u31d7         0.0
# 1        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 2        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 3        49bb5a3c944b8fc337981cc7a9ccae41u31d7         1.0
# 4        a921612b85a1494456e74c09393ccb65ylp4y         0.0
# ...                                        ...         ...
# 4585105  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585106  7ade70030d559a6c255be2f6feca17acnrqs0         0.0
# 4585107  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585108  7ade70030d559a6c255be2f6feca17acnrqs0         1.0
# 4585109  7ade70030d559a6c255be2f6feca17acnrqs0         0.0
#
# [4585110 rows x 2 columns]
